# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahammad-Haroon/Data-Analysis-Projects/blob/main/Data_Cleaning_Analysis_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Create the Dataset

# %%
# Raw data dictionary
data = {
    'Order_ID': [1001, 1002, 1003, 1004, 1005, 1005, 1006, 1007, 1008, 1009, 1010, 1011],
    ' Region ': ['north', 'South', 'EAST', 'west', 'North', 'North', 'south', 'East', 'WEST', 'north', 'South', 'east'],
    'Category': ['Electronics', 'electronics', 'Furniture', 'furnture', 'Electronics', 'Electronics', 'Office Supplies', 'office supplies', 'Electronics', 'Furniture', 'Electronics', 'Electronics'],
    'Sales': ['$1200', '$850', '$2500', '$1750', '$1200', '$1200', '$300', '$450', '$1100', np.nan, '$950', '$1300'],
    'Quantity': [5, 3, 2, 1, 5, 5, 7, 4, 6, 2, np.nan, 4],
    'Profit': [200, 120, 400, 250, 200, 200, 50, 60, 180, 90, 150, 220],
    'Order_Date': ['01-01-2024', '02-01-2024', '03-01-2024', '04-01-2024', '01-01-2024', '01-01-2024', '05-01-2024', '06-01-2024', '07-01-2024', '08-01-2024', '09-01-2024', '10-01-2024']
}

df = pd.DataFrame(data)

# %% [markdown]
# #PART 1: DATA INSPECTION

# %% [markdown]
# Display First 5 Rows

# %%
df.head()
# Out:
#    Order_ID  Region      Category  Sales  Quantity  Profit  Order_Date
# 0      1001    north  Electronics  $1200       5.0     200  01-01-2024
# 1      1002    South  electronics   $850       3.0     120  02-01-2024
# 2      1003     EAST    Furniture  $2500       2.0     400  03-01-2024
# 3      1004     west     furnture  $1750       1.0     250  04-01-2024
# 4      1005    North  Electronics  $1200       5.0     200  01-01-2024

# %% [markdown]
# Check DataFrame Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order_ID    12 non-null     int64
#  1    Region     12 non-null     object
#  2   Category    12 non-null     object
#  3   Sales       11 non-null     object
#  4   Quantity    11 non-null     float64
#  5   Profit      12 non-null     int64
#  6   Order_Date  12 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 804.0+ bytes

# %% [markdown]
# Check DataFrame Shape

# %%
df.shape
# Out:
# (12, 7)

# %% [markdown]
# Check Missing Values

# %%
df.isnull().sum()
# Out:
# Order_ID      0
#  Region       0
# Category      0
# Sales         1
# Quantity      1
# Profit        0
# Order_Date    0
# dtype: int64

# %% [markdown]
# Check Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# #PART 2: DATA CLEANING

# %% [markdown]
# Clean Column Names

# %%
df.columns = df.columns.str.strip().str.lower()

# %%
df.columns
# Out:
# Index(['order_id', 'region', 'category', 'sales', 'quantity', 'profit',
#        'order_date'],
#       dtype='object')

# %% [markdown]
# Remove Duplicate Rows

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Fix String Formatting

# %%
df['region'] = df['region'].str.title()
df['category'] = df['category'].str.title()

# %% [markdown]
# Fix Typo in Category

# %%
df['category'] = df['category'].replace('Furnture', 'Furniture')

# %% [markdown]
# Handle Missing Values

# %%
df['sales'] = df['sales'].str.replace('$', '', regex=False)

# %%
#Convert to numeric:

df['sales'] = pd.to_numeric(df['sales'])

# %%
#Now fill missing values.

df['sales'].fillna(df['sales'].mean(), inplace=True)
df['quantity'].fillna(df['quantity'].mean(), inplace=True)
# Out:
# /tmp/ipykernel_543/3814534059.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sales'].fillna(df['sales'].mean(), inplace=True)
# /tmp/ipykernel_543/3814534059.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# #PART 3: TYPE CONVERSION

# %% [markdown]
# Convert Data Types

# %%
df['sales'] = df['sales'].astype(float)
df['quantity'] = df['quantity'].astype(int)
df['profit'] = df['profit'].astype(float)

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %% [markdown]
# Verify Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    11 non-null     int64
#  1   region      11 non-null     object
#  2   category    11 non-null     object
#  3   sales       11 non-null     float64
#  4   quantity    11 non-null     int64
#  5   profit      11 non-null     float64
#  6   order_date  11 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 704.0+ bytes

# %% [markdown]
# #PART 4: DATA ANALYSIS

# %% [markdown]
# Filter Sales Greater Than 1000

# %%
high_sales = df[df['sales'] > 1000]

high_sales
# Out:
#     order_id region     category   sales  quantity  profit order_date
# 0       1001  North  Electronics  1200.0         5   200.0 2024-01-01
# 2       1003   East    Furniture  2500.0         2   400.0 2024-03-01
# 3       1004   West    Furniture  1750.0         1   250.0 2024-04-01
# 4       1005  North  Electronics  1200.0         5   200.0 2024-01-01
# 8       1008   West  Electronics  1100.0         6   180.0 2024-07-01
# 9       1009  North    Furniture  1160.0         2    90.0 2024-08-01
# 11      1011   East  Electronics  1300.0         4   220.0 2024-10-01

# %% [markdown]
# Group by Region (Total Sales)

# %%
region_sales = df.groupby('region')['sales'].sum()

print(region_sales)
# Out:
# region
# East     4250.0
# North    3560.0
# South    2100.0
# West     2850.0
# Name: sales, dtype: float64

# %% [markdown]
# Group by Category (Total Profit)

# %%
category_profit = df.groupby('category')['profit'].sum()

print(category_profit)
# Out:
# category
# Electronics        1070.0
# Furniture           740.0
# Office Supplies     110.0
# Name: profit, dtype: float64

# %% [markdown]
# #PART 5: NUMPY OPERATIONS

# %% [markdown]
# Convert Sales to NumPy Array

# %%
sales_array = df['sales'].to_numpy()

# %% [markdown]
# Apply 10% Price Increase

# %%
updated_sales = sales_array * 1.10

# %% [markdown]
# Print First 5 Values

# %%
updated_sales[:5]
# Out:
# array([1320.,  935., 2750., 1925., 1320.])
